# %% [markdown]
# <a href="https://colab.research.google.com/github/s23170/GS2DIT/blob/main/Class%204_TTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Let's try today to make AI model speak :)

# %% [markdown]
# Install all necessary dependencies and download the models

# %%
import os
# !git clone https://github.com/TensorSpeech/TensorFlowTTS
os.chdir("TensorFlowTTS")
# !pip install  .
os.chdir("..")
import sys
sys.path.append("TensorFlowTTS/")
# Out:
# fatal: destination path 'TensorFlowTTS' already exists and is not an empty directory.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/TensorFlowTTS
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow-gpu==2.7.0
#   Using cached tensorflow_gpu-2.7.0-cp39-cp39-manylinux2010_x86_64.whl (489.7 MB)
# Collecting tensorflow-addons>=0.10.0
#   Using cached tensorflow_addons-0.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
# Requirement already satisfied: setuptools>=38.5.1 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (67.6.1)
# Collecting huggingface_hub==0.0.8
#   Using cached huggingface_hub-0.0.8-py3-none-any.whl (34 kB)
# Requirement already satisfied: librosa>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (0.10.0.post2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (0.12.1)
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (3.7.1)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (6.0)
# Requirement already satisfied: tqdm>=4.26.1 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (4.65.0)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (3.8.0)
# Collecting unidecode>=1.1.1
#   Using cached Unidecode-1.3.6-py3-none-any.whl (235 kB)
# Requirement already satisfied: inflect>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (6.0.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (1.2.2)
# Collecting pyworld>=0.2.10
#   Using cached pyworld-0.3.2.tar.gz (214 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba>=0.48 in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (0.56.4)
# Collecting jamo>=0.4.1
#   Using cached jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Collecting pypinyin
#   Using cached pypinyin-0.48.0-py2.py3-none-any.whl (1.4 MB)
# Collecting g2pM
#   Using cached g2pM-0.1.2.5-py3-none-any.whl (1.7 MB)
# Collecting textgrid
#   Using cached TextGrid-1.5-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from TensorFlowTTS==0.0) (8.1.3)
# Collecting g2p_en
#   Using cached g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
# Collecting dataclasses
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting pyopenjtalk
#   Using cached pyopenjtalk-0.3.0.tar.gz (1.5 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import numpy as np
import soundfile as sf
import yaml

import tensorflow as tf

from tensorflow_tts.inference import TFAutoModel
from tensorflow_tts.inference import AutoProcessor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-55c424e4d3a1> in <cell line: 7>()
#       5 import tensorflow as tf
#       6
# ----> 7 from tensorflow_tts.inference import TFAutoModel
#       8 from tensorflow_tts.inference import AutoProcessor
#
# /content/TensorFlowTTS/tensorflow_tts/inference/__init__.py in <module>
# ----> 1 from tensorflow_tts.inference.auto_model import TFAutoModel
#       2 from tensorflow_tts.inference.auto_config import AutoConfig
#       3 from tensorflow_tts.inference.auto_processor import AutoProcessor
#
# /content/TensorFlowTTS/tensorflow_tts/inference/auto_model.py in <module>
#      22 from collections import OrderedDict
#      23
# ---> 24 from tensorflow_tts.configs import (
#      25     FastSpeechConfig,
#      26     FastSpeech2Config,
#
# /content/TensorFlowTTS/tensorflow_tts/configs/__init__.py in <module>
# ----> 1 from tensorflow_tts.configs.base_config import BaseConfig
#       2 from tensorflow_tts.configs.fastspeech import FastSpeechConfig
#       3 from tensorflow_tts.configs.fastspeech2 import FastSpeech2Config
#       4 from tensorflow_tts.configs.melgan import (
#       5     MelGANDiscriminatorConfig,
#
# /content/TensorFlowTTS/tensorflow_tts/configs/base_config.py in <module>
#      19 import os
#      20
# ---> 21 from tensorflow_tts.utils.utils import CONFIG_FILE_NAME
#      22
#      23
#
# /content/TensorFlowTTS/tensorflow_tts/utils/__init__.py in <module>
# ----> 1 from tensorflow_tts.utils.cleaners import (
#       2     basic_cleaners,
#       3     collapse_whitespace,
#       4     convert_to_ascii,
#       5     english_cleaners,
#
# /content/TensorFlowTTS/tensorflow_tts/utils/cleaners.py in <module>
#      22 import re
#      23
# ---> 24 from tensorflow_tts.utils.korean import tokenize as ko_tokenize
#      25 from tensorflow_tts.utils.number_norm import normalize_numbers
#      26 from unidecode import unidecode
#
# /content/TensorFlowTTS/tensorflow_tts/utils/korean.py in <module>
#      22 import re
#      23
# ---> 24 from jamo import h2j, hangul_to_jamo, j2h, jamo_to_hcj
#      25
#      26 etc_dictionary = {
#
# ModuleNotFoundError: No module named 'jamo'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# initialize fastspeech2 model.
fastspeech2 = TFAutoModel.from_pretrained("tensorspeech/tts-fastspeech2-ljspeech-en")

# initialize mb_melgan model
mb_melgan = TFAutoModel.from_pretrained("tensorspeech/tts-mb_melgan-ljspeech-en")

# inference
processor = AutoProcessor.from_pretrained("tensorspeech/tts-fastspeech2-ljspeech-en")
# Out:
# Downloading:   0%|          | 0.00/125M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.71k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.83k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.57k [00:00<?, ?B/s]

# %% [markdown]
# Provide a text you would like to be said.

# %%
input_ids = processor.text_to_sequence("Recent research at Harvard has shown meditating for as little as 8 weeks, can actually increase the grey matter in the parts of the brain responsible for emotional regulation, and learning.")

# %% [markdown]
# Inference (ask) the model.

# %%
# fastspeech inference
mel_before, mel_after, duration_outputs, _, _ = fastspeech2.inference(
    input_ids=tf.expand_dims(tf.convert_to_tensor(input_ids, dtype=tf.int32), 0),
    speaker_ids=tf.convert_to_tensor([9], dtype=tf.int32),
    speed_ratios=tf.convert_to_tensor([1.0], dtype=tf.float32),
    f0_ratios =tf.convert_to_tensor([1.0], dtype=tf.float32),
    energy_ratios =tf.convert_to_tensor([1.0], dtype=tf.float32),
)

# melgan inference
audio_before = mb_melgan.inference(mel_before)[0, :, 0]
audio_after = mb_melgan.inference(mel_after)[0, :, 0]

# save to file
sf.write('./audio_before.wav', audio_before, 22050, "PCM_16")
sf.write('./audio_after.wav', audio_after, 22050, "PCM_16")

# %%
import IPython.display as ipd

# %% [markdown]
# Listen to the model output.

# %%
ipd.Audio(audio_before, rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
